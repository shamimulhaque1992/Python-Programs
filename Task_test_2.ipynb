# %% [markdown]
# <a href="https://colab.research.google.com/github/shamimulhaque1992/Python-Programs/blob/main/Task_test_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
\available_course_list_1=[]
available_course_list_2=[]
available_course_list_3=[]
available_course_list_4=[]
available_course_list_5=[]
available_course_list_6=[]
available_course_list_7=[]
available_course_list_8=[]
available_course_list_9=[]
available_course_list_10=[]
available_course_list_11=[]
available_course_list_12=[]
course_list_1=[]
course_list_2=[]
course_list_3=[]
course_list_4=[]
course_list_5=[]
course_list_6=[]
course_list_7=[]
course_list_8=[]
course_list_9=[]
course_list_10=[]
course_list_11=[]
course_list_12=[]
completed_course_list=[]
choice="random"
choose="random"

def un_line():
    print("---------------------------")

def menu():
    un_line()
    print("Menu")
    un_line()

    print("1. View Available Course List of All Semester\n")
    print("2. Add Course :\n")
    print("3. Mark a Course Done! :\n")
    print("4. View Updated Course List List :\n")
    print("5. Exit :\n")
    un_line()

    choice=input("Enter Your choice :\n")
    return choice

while choice!="5":
    choice=menu()


    if choice=="1":
        un_line()
        semester=input("Which Semesters Course Do You Want To View?\n")
        if semester=="1":
            print("The available course list of",semester,"semester")
            un_line()
            for course in available_course_list_1:
                print(course)


        elif semester=="2":
            print("The available course list of",semester,"semester")
            un_line()
            for course in available_course_list_2:
                print(course)


        elif semester=="3":
            print("The available course list of",semester,"semester")
            un_line()
            for course in available_course_list_3:
                print(course)


        elif semester=="4":
            print("The available course list of",semester,"semester")
            un_line()
            for course in available_course_list_4:
                print(course)


        elif semester=="5":
            print("The available course list of",semester,"semester")
            un_line()
            for course in available_course_list_5:
                print(course)


        elif semester=="6":
            print("The available course list of",semester,"semester")
            un_line()
            for course in available_course_list_6:
                print(course)


        elif semester=="7":
            print("The available course list of",semester,"semester")
            un_line()
            for course in available_course_list_7:
                print(course)


        elif semester=="8":
            print("The available course list of",semester,"semester")
            un_line()
            for course in available_course_list_8:
                print(course)


        elif semester=="9":
            print("The available course list of",semester,"semester")
            un_line()
            for course in available_course_list_9:
                print(course)


        elif semester=="10":
            print("The available course list of",semester,"semester")
            un_line()
            for course in available_course_list_10:
                print(course)


        elif semester=="11":
            print("The available course list of",semester,"semester")
            un_line()
            for course in available_course_list_11:
                print(course)


        elif semester=="12":
            print("The available course list of",semester,"semester")
            un_line()
            for course in available_course_list_12:
                print(course)


        elif semester=="All":
            print("The available course list of",semester,"semester")
            un_line()

            print("Course list Of 1st semester")
            un_line()
            for course in available_course_list_1:
                print(course)
            un_line()

            print("Course list Of 2nd semester")
            un_line()
            for course in available_course_list_2:
                print(course)
            un_line()

            print("Course list Of 3rd semester")
            un_line()
            for course in available_course_list_3:
                print(course)
            un_line()

            print("Course list Of 4th semester")
            un_line()
            for course in available_course_list_4:
                print(course)
            un_line()

            print("Course list Of 5th semester")
            un_line()
            for course in available_course_list_5:
                print(course)
            un_line()

            print("Course list Of 6th semester")
            un_line()
            for course in available_course_list_6:
                print(course)
            un_line()

            print("Course list Of 7th semester")
            un_line()
            for course in available_course_list_7:
                print(course)
            un_line()

            print("Course list Of 8th semester")
            un_line()
            for course in available_course_list_8:
                print(course)
            un_line()

            print("Course list Of 9th semester")
            un_line()
            for course in available_course_list_9:
                print(course)
            un_line()

            print("Course list Of 10th semester")
            un_line()
            for course in available_course_list_10:
                print(course)
            un_line()

            print("Course list Of 11th semester")
            un_line()
            for course in available_course_list_11:
                print(course)
            un_line()

            print("Course list Of 12th semester")
            un_line()
            for course in available_course_list_12:
                print(course)
            un_line()

        else:
            print("Invalid Choice! or Course Haven't been Assign Yet. Assign Some Course First or Please Enter A valid Choice or write All to see All Courses")

    elif choice=="2":
        semester=input("In Which Semester Do You want to insert The Course ?\n")
        if semester =="1":
            course = input("Enter The course name into the course list :\n")
            course_list_1.append(course)
            available_course_list_1.append(course)
            print("Course", course, "is added to the 1st semester course list \n")


            choose = input("Do You Want to Add More Course in 1st Semester? \n")
            while choose == "Yes":
                course = input("Enter The course name into the course list :\n")
                course_list_1.append(course)
                available_course_list_1.append(course)
                print("Course", course, "is added to the 1st semester course list \n")
                choose = input("Do You Want to Add More Course in 1st Semester? \n")


        elif semester =="2":
            course = input("Enter The course name into the course list :\n")
            course_list_2.append(course)
            available_course_list_2.append(course)
            print("Course", course, "is added to the 2nd semester course list \n")


            choose = input("Do You Want to Add More Course in 2nd Semester? \n")
            while choose == "Yes":
                course = input("Enter The course name into the course list :\n")
                course_list_2.append(course)
                available_course_list_2.append(course)
                print("Course", course, "is added to the 2nd semester course list \n")
                choose = input("Do You Want to Add More Course in 2nd Semester? \n")


        elif semester =="3":
            course = input("Enter The course name into the course list :\n")
            course_list_3.append(course)
            available_course_list_3.append(course)
            print("Course", course, "is added to the 3rd semester course list \n")


            choose = input("Do You Want to Add More Course in 3rd Semester? \n")
            while choose == "Yes":
                course = input("Enter The course name into the course list :\n")
                course_list_3.append(course)
                available_course_list_3.append(course)
                print("Course", course, "is added to the 3rd semester course list \n")
                choose = input("Do You Want to Add More Course in 3rd Semester? \n")


        elif semester =="4":
            course = input("Enter The course name into the course list :\n")
            course_list_4.append(course)
            available_course_list_4.append(course)
            print("Course", course, "is added to the 4th semester course list \n")


            choose = input("Do You Want to Add More Course in 4th Semester? \n")
            while choose == "Yes":
                course = input("Enter The course name into the course list :\n")
                course_list_4.append(course)
                available_course_list_4.append(course)
                print("Course", course, "is added to the 4th semester course list \n")
                choose = input("Do You Want to Add More Course in 4th Semester? \n")



        elif semester =="5":
            course = input("Enter The course name into the course list :\n")
            course_list_5.append(course)
            available_course_list_5.append(course)
            print("Course", course, "is added to the 5th semester course list \n")


            choose = input("Do You Want to Add More Course in 5th Semester? \n")
            while choose == "Yes":
                course = input("Enter The course name into the course list :\n")
                course_list_5.append(course)
                available_course_list_5.append(course)
                print("Course", course, "is added to the 5th semester course list \n")
                choose = input("Do You Want to Add More Course in 5th Semester? \n")


        elif semester =="6":
            course = input("Enter The course name into the course list :\n")
            course_list_6.append(course)
            available_course_list_6.append(course)
            print("Course", course, "is added to the 6th semester course list \n")


            choose = input("Do You Want to Add More Course in 6th Semester? \n")
            while choose == "Yes":
                course = input("Enter The course name into the course list :\n")
                course_list_6.append(course)
                available_course_list_6.append(course)
                print("Course", course, "is added to the 6th semester course list \n")
                choose = input("Do You Want to Add More Course in 6th Semester? \n")


        elif semester =="7":
            course = input("Enter The course name into the course list :\n")
            course_list_7.append(course)
            available_course_list_7.append(course)
            print("Course", course, "is added to the 7th semester course list \n")


            choose = input("Do You Want to Add More Course in 7th Semester? \n")
            while choose == "Yes":
                course = input("Enter The course name into the course list :\n")
                course_list_7.append(course)
                available_course_list_7.append(course)
                print("Course", course, "is added to the 7th semester course list \n")
                choose = input("Do You Want to Add More Course in 7th Semester? \n")


        elif semester =="8":
            course = input("Enter The course name into the course list :\n")
            course_list_8.append(course)
            available_course_list_8.append(course)
            print("Course", course, "is added to the 8th semester course list \n")


            choose = input("Do You Want to Add More Course in 8th Semester? \n")
            while choose == "Yes":
                course = input("Enter The course name into the course list :\n")
                course_list_8.append(course)
                available_course_list_8.append(course)
                print("Course", course, "is added to the 8th semester course list \n")
                choose = input("Do You Want to Add More Course in 8th Semester? \n")


        elif semester =="9":
            course = input("Enter The course name into the course list :\n")
            course_list_9.append(course)
            available_course_list_9.append(course)
            print("Course", course, "is added to the 9th semester course list \n")


            choose = input("Do You Want to Add More Course in 9th Semester? \n")
            while choose == "Yes":
                course = input("Enter The course name into the course list :\n")
                course_list_9.append(course)
                available_course_list_9.append(course)
                print("Course", course, "is added to the 9th semester course list \n")
                choose = input("Do You Want to Add More Course in 9th Semester? \n")


        elif semester =="10":
            course = input("Enter The course name into the course list :\n")
            course_list_10.append(course)
            available_course_list_10.append(course)
            print("Course", course, "is added to the 10th semester course list \n")


            choose = input("Do You Want to Add More Course in 10th Semester? \n")
            while choose == "Yes":
                course = input("Enter The course name into the course list :\n")
                course_list_10.append(course)
                available_course_list_10.append(course)
                print("Course", course, "is added to the 10th semester course list \n")
                choose = input("Do You Want to Add More Course in 10th Semester? \n")


        elif semester =="11":
            course = input("Enter The course name into the course list :\n")
            course_list_11.append(course)
            available_course_list_11.append(course)
            print("Course", course, "is added to the 11th semester course list \n")


            choose = input("Do You Want to Add More Course in 11th Semester? \n")
            while choose == "Yes":
                course = input("Enter The course name into the course list :\n")
                course_list_11.append(course)
                available_course_list_11.append(course)
                print("Course", course, "is added to the 11th semester course list \n")
                choose = input("Do You Want to Add More Course in 11th Semester? \n")


        elif semester =="12":
            course = input("Enter The course name into the course list :\n")
            course_list_12.append(course)
            available_course_list_12.append(course)
            print("Course", course, "is added to the 12th semester course list \n")


            choose = input("Do You Want to Add More Course in 12th Semester? \n")
            while choose == "Yes":
                course = input("Enter The course name into the course list :\n")
                course_list_12.append(course)
                available_course_list_12.append(course)
                print("Course", course, "is added to the 12th semester course list \n")
                choose = input("Do You Want to Add More Course in 12th Semester? \n")


    elif choice=="3":
        semester=input("In Which Semester Are You In ?\n")
        if semester == "1":
            course = input("Enter The Name of the course Which Have been Completed :\n")
            if course in course_list_1:
                course_list_1.remove(course)
                print("The course", course, "is removed from the course list")
                completed_course_list.append(course)
                print("Course",course,"is added into Completed Course List!\n")


                choose = input("Do You Want to remove More Course from 1st Semester? \n")
                while choose == "Yes":
                    course = input("Enter The course name to be removed from the course list :\n")
                    course_list_1.remove(course)
                    print("Course", course, "is removed from the 1st semester course list \n")
                    completed_course_list.append(course)
                    print("Course", course, "is added into Completed Course List!\n")
                    choose = input("Do You Want to remove More Course from 1st Semester? \n")

            else:
                print("Course not Found or haven't taken yet \n")


        elif semester == "2":
            course = input("Enter The Name of the course Which Have been Completed :\n")
            if course in course_list_2:
                course_list_2.remove(course)
                print("The course", course, "is removed from the course list")
                completed_course_list.append(course)
                print("Course", course, "is added into Completed Course List!\n")

                choose = input("Do You Want to remove More Course from 2nd Semester? \n")
                while choose == "Yes":
                    course = input("Enter The course name to be removed from the course list :\n")
                    course_list_2.remove(course)
                    print("Course", course, "is removed from the 2nd semester course list \n")
                    completed_course_list.append(course)
                    print("Course", course, "is added into Completed Course List!\n")
                    choose = input("Do You Want to remove More Course from 2nd Semester? \n")
            else:
                print("Course not Found or haven't taken yet \n")


        elif semester == "3":
            course = input("Enter The Name of the course Which Have been Completed :\n")
            if course in course_list_3:
                course_list_3.remove(course)
                print("The course", course, "is removed from the course list")
                completed_course_list.append(course)
                print("Course", course, "is added into Completed Course List!\n")

                choose = input("Do You Want to remove More Course from 3rd Semester? \n")
                while choose == "Yes":
                    course = input("Enter The course name to be removed from the course list :\n")
                    course_list_3.remove(course)
                    print("Course", course, "is removed from the 3rd semester course list \n")
                    completed_course_list.append(course)
                    print("Course", course, "is added into Completed Course List!\n")
                    choose = input("Do You Want to remove More Course from 3rd Semester? \n")
            else:
                print("Course not Found or haven't taken yet \n")


        elif semester == "4":
            course = input("Enter The Name of the course Which Have been Completed :\n")
            if course in course_list_4:
                course_list_4.remove(course)
                print("The course", course, "is removed from the course list")
                completed_course_list.append(course)
                print("Course", course, "is added into Completed Course List!\n")

                choose = input("Do You Want to remove More Course from 4th Semester? \n")
                while choose == "Yes":
                    course = input("Enter The course name to be removed from the course list :\n")
                    course_list_4.remove(course)
                    print("Course", course, "is removed from the 4th semester course list \n")
                    completed_course_list.append(course)
                    print("Course", course, "is added into Completed Course List!\n")
                    choose = input("Do You Want to remove More Course from 4th Semester? \n")
            else:
                print("Course not Found or haven't taken yet \n")


        elif semester == "5":
            course = input("Enter The Name of the course Which Have been Completed :\n")
            if course in course_list_5:
                course_list_5.remove(course)
                print("The course", course, "is removed from the course list")
                completed_course_list.append(course)
                print("Course", course, "is added into Completed Course List!\n")

                choose = input("Do You Want to remove More Course from 5th Semester? \n")
                while choose == "Yes":
                    course = input("Enter The course name to be removed from the course list :\n")
                    course_list_5.remove(course)
                    print("Course", course, "is removed from the 5th semester course list \n")
                    completed_course_list.append(course)
                    print("Course", course, "is added into Completed Course List!\n")
                    choose = input("Do You Want to remove More Course from 5th Semester? \n")
            else:
                print("Course not Found or haven't taken yet \n")


        elif semester == "6":
            course = input("Enter The Name of the course Which Have been Completed :\n")
            if course in course_list_6:
                course_list_6.remove(course)
                print("The course", course, "is removed from the course list")
                completed_course_list.append(course)
                print("Course", course, "is added into Completed Course List!\n")

                choose = input("Do You Want to remove More Course from 6th Semester? \n")
                while choose == "Yes":
                    course = input("Enter The course name to be removed from the course list :\n")
                    course_list_6.remove(course)
                    print("Course", course, "is removed from the 6th semester course list \n")
                    completed_course_list.append(course)
                    print("Course", course, "is added into Completed Course List!\n")
                    choose = input("Do You Want to remove More Course from 6th Semester? \n")
            else:
                print("Course not Found or haven't taken yet \n")


        elif semester == "7":
            course = input("Enter The Name of the course Which Have been Completed :\n")
            if course in course_list_7:
                course_list_7.remove(course)
                print("The course", course, "is removed from the course list")
                completed_course_list.append(course)
                print("Course", course, "is added into Completed Course List!\n")

                choose = input("Do You Want to remove More Course from 7th Semester? \n")
                while choose == "Yes":
                    course = input("Enter The course name to be removed from the course list :\n")
                    course_list_7.remove(course)
                    print("Course", course, "is removed from the 7th semester course list \n")
                    completed_course_list.append(course)
                    print("Course", course, "is added into Completed Course List!\n")
                    choose = input("Do You Want to remove More Course from 7th Semester? \n")
            else:
                print("Course not Found or haven't taken yet \n")


        elif semester == "8":
            course = input("Enter The Name of the course Which Have been Completed :\n")
            if course in course_list_8:
                course_list_8.remove(course)
                print("The course", course, "is removed from the course list")
                completed_course_list.append(course)
                print("Course", course, "is added into Completed Course List!\n")

                choose = input("Do You Want to remove More Course from 8th Semester? \n")
                while choose == "Yes":
                    course = input("Enter The course name to be removed from the course list :\n")
                    course_list_8.remove(course)
                    print("Course", course, "is removed from the 8th semester course list \n")
                    completed_course_list.append(course)
                    print("Course", course, "is added into Completed Course List!\n")
                    choose = input("Do You Want to remove More Course from 8th Semester? \n")
            else:
                print("Course not Found or haven't taken yet \n")


        elif semester == "9":
            course = input("Enter The Name of the course Which Have been Completed :\n")
            if course in course_list_9:
                course_list_9.remove(course)
                print("The course", course, "is removed from the course list")
                completed_course_list.append(course)
                print("Course", course, "is added into Completed Course List!\n")

                choose = input("Do You Want to remove More Course from 9th Semester? \n")
                while choose == "Yes":
                    course = input("Enter The course name to be removed from the course list :\n")
                    course_list_9.remove(course)
                    print("Course", course, "is removed from the 9th semester course list \n")
                    completed_course_list.append(course)
                    print("Course", course, "is added into Completed Course List!\n")
                    choose = input("Do You Want to remove More Course from 9th Semester? \n")
            else:
                print("Course not Found or haven't taken yet \n")


        elif semester == "10":
            course = input("Enter The Name of the course Which Have been Completed :\n")
            if course in course_list_10:
                course_list_10.remove(course)
                print("The course", course, "is removed from the course list")
                completed_course_list.append(course)
                print("Course", course, "is added into Completed Course List!\n")

                choose = input("Do You Want to remove More Course from 10th Semester? \n")
                while choose == "Yes":
                    course = input("Enter The course name to be removed from the course list :\n")
                    course_list_10.remove(course)
                    print("Course", course, "is removed from the 10th semester course list \n")
                    completed_course_list.append(course)
                    print("Course", course, "is added into Completed Course List!\n")
                    choose = input("Do You Want to remove More Course from 10th Semester? \n")
            else:
                print("Course not Found or haven't taken yet \n")


        elif semester == "11":
            course = input("Enter The Name of the course Which Have been Completed :\n")
            if course in course_list_11:
                course_list_11.remove(course)
                print("The course", course, "is removed from the course list")
                completed_course_list.append(course)
                print("Course", course, "is added into Completed Course List!\n")

                choose = input("Do You Want to remove More Course from 11th Semester? \n")
                while choose == "Yes":
                    course = input("Enter The course name to be removed from the course list :\n")
                    course_list_11.remove(course)
                    print("Course", course, "is removed from the 11th semester course list \n")
                    completed_course_list.append(course)
                    print("Course", course, "is added into Completed Course List!\n")
                    choose = input("Do You Want to remove More Course from 11th Semester? \n")
            else:
                print("Course not Found or haven't taken yet \n")


        elif semester == "12":
            course = input("Enter The Name of the course Which Have been Completed :\n")
            if course in course_list_12:
                course_list_12.remove(course)
                print("The course", course, "is removed from the course list")
                completed_course_list.append(course)
                print("Course", course, "is added into Completed Course List!\n")

                choose = input("Do You Want to remove More Course from 12th Semester? \n")
                while choose == "Yes":
                    course = input("Enter The course name to be removed from the course list :\n")
                    course_list_12.remove(course)
                    print("Course", course, "is removed from the 12th semester course list \n")
                    completed_course_list.append(course)
                    print("Course", course, "is added into Completed Course List!\n")
                    choose = input("Do You Want to remove More Course from 12th Semester? \n")
            else:
                print("Course not Found or haven't taken yet \n")



    elif choice=="4":
        un_line()
        semester=input("Which Semesters Course Do You Want To View?\n")
        if semester=="1":
            print("The course list of",semester,"semester")
            un_line()
            for course in course_list_1:
                print(course)


        elif semester=="2":
            print("The course list of",semester,"semester")
            un_line()
            for course in course_list_2:
                print(course)


        elif semester=="3":
            print("The course list of",semester,"semester")
            un_line()
            for course in course_list_3:
                print(course)


        elif semester=="4":
            print("The course list of",semester,"semester")
            un_line()
            for course in course_list_4:
                print(course)


        elif semester=="5":
            print("The course list of",semester,"semester")
            un_line()
            for course in course_list_5:
                print(course)


        elif semester=="6":
            print("The course list of",semester,"semester")
            un_line()
            for course in course_list_6:
                print(course)


        elif semester=="7":
            print("The course list of",semester,"semester")
            un_line()
            for course in course_list_7:
                print(course)


        elif semester=="8":
            print("The course list of",semester,"semester")
            un_line()
            for course in course_list_8:
                print(course)


        elif semester=="9":
            print("The course list of",semester,"semester")
            un_line()
            for course in course_list_9:
                print(course)


        elif semester=="10":
            print("The course list of",semester,"semester")
            un_line()
            for course in course_list_10:
                print(course)


        elif semester=="11":
            print("The course list of",semester,"semester")
            un_line()
            for course in course_list_11:
                print(course)


        elif semester=="12":
            print("The course list of",semester,"semester")
            un_line()
            for course in course_list_12:
                print(course)


        elif semester=="All":
            print("The course list of",semester,"semester")
            un_line()
            for course in course_list_1:
                print("Course list Of 1st semester")
                un_line()
                print(course)

            un_line()
            for course in course_list_2:
                print("Course list Of 2nd semester")
                un_line()
                print(course)

            un_line()
            for course in course_list_3:
                print("Course list Of 3rd semester")
                un_line()
                print(course)

            un_line()
            for course in course_list_4:
                print("Course list Of 4th semester")
                un_line()
                print(course)

            un_line()
            for course in course_list_5:
                print("Course list Of 5th semester")
                un_line()
                print(course)

            un_line()
            for course in course_list_6:
                print("Course list Of 6th semester")
                un_line()
                print(course)

            un_line()
            for course in course_list_7:
                print("Course list Of 7th semester")
                un_line()
                print(course)

            un_line()
            for course in course_list_8:
                print("Course list Of 8th semester")
                un_line()
                print(course)

            un_line()
            for course in course_list_9:
                print("Course list Of 9th semester")
                un_line()
                print(course)

            un_line()
            for course in course_list_10:
                print("Course list Of 10th semester")
                un_line()
                print(course)

            un_line()
            for course in course_list_11:
                print("Course list Of 11th semester")
                un_line()
                print(course)

            un_line()
            for course in course_list_12:
                print("Course list Of 12th semester")
                un_line()
                print(course)

        else:
            print("Invalid Choice! Please Enter A valid Choice of write All to see All Courses")


    elif choice=="5":
        print("GoodBuy!!!")

    else:
        print("Invalid Choice! Please chose one of 1, 2, 3 or 4")
# Out:
# ---------------------------
# Menu
# ---------------------------
# 1. View Available Course List of All Semester
#
# 2. Add Course :
#
# 3. Mark a Course Done! :
#
# 4. View Updated Course List List :
#
# 5. Exit :
#
# ---------------------------
# Enter Your choice :
# 2
# In Which Semester Do You want to insert The Course ?
# 1
# Enter The course name into the course list :
# Computer Fundamental
# Course Computer Fundamental is added to the 1st semester course list
#
# Do You Want to Add More Course in 1st Semester?
# Yes
# Enter The course name into the course list :
# Math 1
# Course Math 1 is added to the 1st semester course list
#
# Do You Want to Add More Course in 1st Semester?
# Yes
# Enter The course name into the course list :
# Physics 1
# Course Physics 1 is added to the 1st semester course list
#
# Do You Want to Add More Course in 1st Semester?
# Yes
# Enter The course name into the course list :
# Basic Fundamental English
# Course Basic Fundamental English is added to the 1st semester course list
#
# Do You Want to Add More Course in 1st Semester?
# No
# ---------------------------
# Menu
# ---------------------------
# 1. View Available Course List of All Semester
#
# 2. Add Course :
#
# 3. Mark a Course Done! :
#
# 4. View Updated Course List List :
#
# 5. Exit :
#
# ---------------------------
# Enter Your choice :
# 2
# In Which Semester Do You want to insert The Course ?
# 2
# Enter The course name into the course list :
# Programming And Problem Solving
# Course Programming And Problem Solving is added to the 2nd semester course list
#
# Do You Want to Add More Course in 2nd Semester?
# Yes
# Enter The course name into the course list :
# Programming And Problem Solving Lab
# Course Programming And Problem Solving Lab is added to the 2nd semester course list
#
# Do You Want to Add More Course in 2nd Semester?
# Yes
# Enter The course name into the course list :
# Physics 2
# Course Physics 2 is added to the 2nd semester course list
#
# Do You Want to Add More Course in 2nd Semester?
# Yes
# Enter The course name into the course list :
# Physics 2 Lab
# Course Physics 2 Lab is added to the 2nd semester course list
#
# Do You Want to Add More Course in 2nd Semester?
# Yes
# Enter The course name into the course list :
# Writing and Comprehension
# Course Writing and Comprehension is added to the 2nd semester course list
#
# Do You Want to Add More Course in 2nd Semester?
# No
# ---------------------------
# Menu
# ---------------------------
# 1. View Available Course List of All Semester
#
# 2. Add Course :
#
# 3. Mark a Course Done! :
#
# 4. View Updated Course List List :
#
# 5. Exit :
#
# ---------------------------
# Enter Your choice :
# 2
# In Which Semester Do You want to insert The Course ?
# 3
# Enter The course name into the course list :
# Ordinary and Partial Differential Equation
# Course Ordinary and Partial Differential Equation is added to the 3rd semester course list
#
# Do You Want to Add More Course in 3rd Semester?
# Yes
# Enter The course name into the course list :
# Data Structure
# Course Data Structure is added to the 3rd semester course list
#
# Do You Want to Add More Course in 3rd Semester?
# Yes
# Enter The course name into the course list :
# Data Structure Lab
# Course Data Structure Lab is added to the 3rd semester course list
#
# Do You Want to Add More Course in 3rd Semester?
# Yes
# Enter The course name into the course list :
# Electrical Circuits
# Course Electrical Circuits is added to the 3rd semester course list
#
# Do You Want to Add More Course in 3rd Semester?
# Yes
# Enter The course name into the course list :
# Electrical Circuits Lab
# Course Electrical Circuits Lab is added to the 3rd semester course list
#
# Do You Want to Add More Course in 3rd Semester?
# Discrete Mathematics
# ---------------------------
# Menu
# ---------------------------
# 1. View Available Course List of All Semester
#
# 2. Add Course :
#
# 3. Mark a Course Done! :
#
# 4. View Updated Course List List :
#
# 5. Exit :
#
# ---------------------------
# Enter Your choice :
# 2
# In Which Semester Do You want to insert The Course ?
# 3
# Enter The course name into the course list :
# Discrete Mathematics
# Course Discrete Mathematics is added to the 3rd semester course list
#
# Do You Want to Add More Course in 3rd Semester?
# No
# ---------------------------
# Menu
# ---------------------------
# 1. View Available Course List of All Semester
#
# 2. Add Course :
#
# 3. Mark a Course Done! :
#
# 4. View Updated Course List List :
#
# 5. Exit :
#
# ---------------------------
# Enter Your choice :
# 2
# In Which Semester Do You want to insert The Course ?
# 4
# Enter The course name into the course list :
# Engineering Mathematics
# Course Engineering Mathematics is added to the 4th semester course list
#
# Do You Want to Add More Course in 4th Semester?
# Yes
# Enter The course name into the course list :
# OOP
# Course OOP is added to the 4th semester course list
#
# Do You Want to Add More Course in 4th Semester?
# Yes
# Enter The course name into the course list :
# OOP Lab
# Course OOP Lab is added to the 4th semester course list
#
# Do You Want to Add More Course in 4th Semester?
# Yes
# Enter The course name into the course list :
# Bangladesh Studies
# Course Bangladesh Studies  is added to the 4th semester course list
#
# Do You Want to Add More Course in 4th Semester?
# Yes
# Enter The course name into the course list :
# Digital Electronics
# Course Digital Electronics is added to the 4th semester course list
#
# Do You Want to Add More Course in 4th Semester?
# Yes
# Enter The course name into the course list :
# Digital Electronics Lab
# Course Digital Electronics Lab is added to the 4th semester course list
#
# Do You Want to Add More Course in 4th Semester?
# Yes
# Enter The course name into the course list :
# Null
# Course Null is added to the 4th semester course list
#
# Do You Want to Add More Course in 4th Semester?
# No
# ---------------------------
# Menu
# ---------------------------
# 1. View Available Course List of All Semester
#
# 2. Add Course :
#
# 3. Mark a Course Done! :
#
# 4. View Updated Course List List :
#
# 5. Exit :
#
# ---------------------------
# Enter Your choice :
# 2
# In Which Semester Do You want to insert The Course ?
# 5
# Enter The course name into the course list :
# Algorithms
# Course Algorithms is added to the 5th semester course list
#
# Do You Want to Add More Course in 5th Semester?
# Yes
# Enter The course name into the course list :
# Algorithms Lab
# Course Algorithms Lab is added to the 5th semester course list
#
# Do You Want to Add More Course in 5th Semester?
# Yes
# Enter The course name into the course list :
# Electronics Device and Circuits
# Course Electronics Device and Circuits is added to the 5th semester course list
#
# Do You Want to Add More Course in 5th Semester?
# Yes
# Enter The course name into the course list :
# Electronics Device and Circuits Lab
# Course Electronics Device and Circuits Lab is added to the 5th semester course list
#
# Do You Want to Add More Course in 5th Semester?
# Yes
# Enter The course name into the course list :
# Statistics and Probability
# Course Statistics and Probability is added to the 5th semester course list
#
# Do You Want to Add More Course in 5th Semester?
# No
# ---------------------------
# Menu
# ---------------------------
# 1. View Available Course List of All Semester
#
# 2. Add Course :
#
# 3. Mark a Course Done! :
#
# 4. View Updated Course List List :
#
# 5. Exit :
#
# ---------------------------
# Enter Your choice :
# 2
# In Which Semester Do You want to insert The Course ?
# 6
# Enter The course name into the course list :
# Bio Informatics
# Course Bio Informatics is added to the 6th semester course list
#
# Do You Want to Add More Course in 6th Semester?
# Yes
# Enter The course name into the course list :
# Numerical Methods
# Course Numerical Methods  is added to the 6th semester course list
#
# Do You Want to Add More Course in 6th Semester?
# Yes
# Enter The course name into the course list :
# Data Communications
# Course Data Communications is added to the 6th semester course list
#
# Do You Want to Add More Course in 6th Semester?
# Yes
# Enter The course name into the course list :
# Microprocessors and Assembly Language
# Course Microprocessors and Assembly Language is added to the 6th semester course list
#
# Do You Want to Add More Course in 6th Semester?
# Yes
# Enter The course name into the course list :
# Microprocessors and Assembly Language lab
# Course Microprocessors and Assembly Language lab is added to the 6th semester course list
#
# Do You Want to Add More Course in 6th Semester?
# No
# ---------------------------
# Menu
# ---------------------------
# 1. View Available Course List of All Semester
#
# 2. Add Course :
#
# 3. Mark a Course Done! :
#
# 4. View Updated Course List List :
#
# 5. Exit :
#
# ---------------------------
# Enter Your choice :
# 2
# In Which Semester Do You want to insert The Course ?
# 7
# Enter The course name into the course list :
# DBMS
# Course DBMS is added to the 7th semester course list
#
# Do You Want to Add More Course in 7th Semester?
# Yes
# Enter The course name into the course list :
# DBMS Lab
# Course DBMS Lab is added to the 7th semester course list
#
# Do You Want to Add More Course in 7th Semester?
# Yes
# Enter The course name into the course list :
# Computer Networks
# Course Computer Networks is added to the 7th semester course list
#
# Do You Want to Add More Course in 7th Semester?
# Yes
# Enter The course name into the course list :
# Computer Networks Lab
# Course Computer Networks Lab is added to the 7th semester course list
#
# Do You Want to Add More Course in 7th Semester?
# Yes
# Enter The course name into the course list :
# Economics
# Course Economics is added to the 7th semester course list
#
# Do You Want to Add More Course in 7th Semester?
# No
# ---------------------------
# Menu
# ---------------------------
# 1. View Available Course List of All Semester
#
# 2. Add Course :
#
# 3. Mark a Course Done! :
#
# 4. View Updated Course List List :
#
# 5. Exit :
#
# ---------------------------
# Enter Your choice :
# 2
# In Which Semester Do You want to insert The Course ?
# 8
# Enter The course name into the course list :
# OS
# Course OS is added to the 8th semester course list
#
# Do You Want to Add More Course in 8th Semester?
# Yes
# Enter The course name into the course list :
# OS Lab
# Course OS Lab is added to the 8th semester course list
#
# Do You Want to Add More Course in 8th Semester?
# Yes
# Enter The course name into the course list :
# System Analysis and Design
# Course System Analysis and Design is added to the 8th semester course list
#
# Do You Want to Add More Course in 8th Semester?
# Yes
# Enter The course name into the course list :
# Computer Architecture
# Course Computer Architecture is added to the 8th semester course list
#
# Do You Want to Add More Course in 8th Semester?
# Yes
# Enter The course name into the course list :
# Art of Living
# Course Art of Living is added to the 8th semester course list
#
# Do You Want to Add More Course in 8th Semester?
# No
# ---------------------------
# Menu
# ---------------------------
# 1. View Available Course List of All Semester
#
# 2. Add Course :
#
# 3. Mark a Course Done! :
#
# 4. View Updated Course List List :
#
# 5. Exit :
#
# ---------------------------
# Enter Your choice :
# 2
# In Which Semester Do You want to insert The Course ?
# 9
# Enter The course name into the course list :
# Accounting
# Course Accounting is added to the 9th semester course list
#
# Do You Want to Add More Course in 9th Semester?
# Yes
# Enter The course name into the course list :
# Wireless Programming
# Course Wireless Programming is added to the 9th semester course list
#
# Do You Want to Add More Course in 9th Semester?
# Yes
# Enter The course name into the course list :
# Software Engineering
# Course Software Engineering is added to the 9th semester course list
#
# Do You Want to Add More Course in 9th Semester?
# Yes
# Enter The course name into the course list :
# Compiler Design
# Course Compiler Design is added to the 9th semester course list
#
# Do You Want to Add More Course in 9th Semester?
# Yes
# Enter The course name into the course list :
# Compiler Design Lab
# Course Compiler Design Lab is added to the 9th semester course list
#
# Do You Want to Add More Course in 9th Semester?
# No
# ---------------------------
# Menu
# ---------------------------
# 1. View Available Course List of All Semester
#
# 2. Add Course :
#
# 3. Mark a Course Done! :
#
# 4. View Updated Course List List :
#
# 5. Exit :
#
# ---------------------------
# Enter Your choice :
# 2
# In Which Semester Do You want to insert The Course ?
# 10
# Enter The course name into the course list :
# AI
# Course AI is added to the 10th semester course list
#
# Do You Want to Add More Course in 10th Semester?
# Yes
# Enter The course name into the course list :
# AI Lab
# Course AI Lab is added to the 10th semester course list
#
# Do You Want to Add More Course in 10th Semester?
# Yes
# Enter The course name into the course list :
# Simulation and Modeling
# Course Simulation and Modeling  is added to the 10th semester course list
#
# Do You Want to Add More Course in 10th Semester?
# Yes
# Enter The course name into the course list :
# Simulation and Modeling Lab
# Course Simulation and Modeling Lab is added to the 10th semester course list
#
# Do You Want to Add More Course in 10th Semester?
# Yes
# Enter The course name into the course list :
# Web Design
# Course Web Design is added to the 10th semester course list
#
# Do You Want to Add More Course in 10th Semester?
# Yes
# Enter The course name into the course list :
# Web Design Lab
# Course Web Design Lab is added to the 10th semester course list
#
# Do You Want to Add More Course in 10th Semester?
# No
# ---------------------------
# Menu
# ---------------------------
# 1. View Available Course List of All Semester
#
# 2. Add Course :
#
# 3. Mark a Course Done! :
#
# 4. View Updated Course List List :
#
# 5. Exit :
#
# ---------------------------
# Enter Your choice :
# 2
# In Which Semester Do You want to insert The Course ?
# 11
# Enter The course name into the course list :
# Computer Graphics
# Course Computer Graphics is added to the 11th semester course list
#
# Do You Want to Add More Course in 11th Semester?
# Yes
# Enter The course name into the course list :
# Computer Graphics Lab
# Course Computer Graphics Lab is added to the 11th semester course list
#
# Do You Want to Add More Course in 11th Semester?
# Yes
# Enter The course name into the course list :
# Embedded System
# Course Embedded System is added to the 11th semester course list
#
# Do You Want to Add More Course in 11th Semester?
# Yes
# Enter The course name into the course list :
# Elective 1
# Course Elective 1 is added to the 11th semester course list
#
# Do You Want to Add More Course in 11th Semester?
# Yes
# Enter The course name into the course list :
# Project/Internship 1
# Course Project/Internship 1 is added to the 11th semester course list
#
# Do You Want to Add More Course in 11th Semester?
# No
# ---------------------------
# Menu
# ---------------------------
# 1. View Available Course List of All Semester
#
# 2. Add Course :
#
# 3. Mark a Course Done! :
#
# 4. View Updated Course List List :
#
# 5. Exit :
#
# ---------------------------
# Enter Your choice :
# 2
# In Which Semester Do You want to insert The Course ?
# 12
# Enter The course name into the course list :
# Social and Professional Issue in Computing
# Course Social and Professional Issue in Computing is added to the 12th semester course list
#
# Do You Want to Add More Course in 12th Semester?
# Yes
# Enter The course name into the course list :
# Elective 2
# Course Elective 2 is added to the 12th semester course list
#
# Do You Want to Add More Course in 12th Semester?
# Yes
# Enter The course name into the course list :
# Project/Internship 2
# Course Project/Internship 2 is added to the 12th semester course list
#
# Do You Want to Add More Course in 12th Semester?
# No
# ---------------------------
# Menu
# ---------------------------
# 1. View Available Course List of All Semester
#
# 2. Add Course :
#
# 3. Mark a Course Done! :
#
# 4. View Updated Course List List :
#
# 5. Exit :
#
# ---------------------------
# Enter Your choice :
# 3
# In Which Semester Are You In ?
# 1
# Enter The Name of the course Which Have been Completed :
# Computer Fundamental
# The course Computer Fundamental is removed from the course list
# Course Computer Fundamental is added into Completed Course List!
#
# Do You Want to remove More Course from 1st Semester?
# No
# ---------------------------
# Menu
# ---------------------------
# 1. View Available Course List of All Semester
#
# 2. Add Course :
#
# 3. Mark a Course Done! :
#
# 4. View Updated Course List List :
#
# 5. Exit :
#
# ---------------------------
# Enter Your choice :
# 1
# ---------------------------
# Which Semesters Course Do You Want To View?
# All
# The available course list of All semester
# ---------------------------
# Course list Of 1st semester
# ---------------------------
# Computer Fundamental
# Math 1
# Physics 1
# Basic Fundamental English
# ---------------------------
# Course list Of 2nd semester
# ---------------------------
# Programming And Problem Solving
# Programming And Problem Solving Lab
# Physics 2
# Physics 2 Lab
# Writing and Comprehension
# ---------------------------
# Course list Of 3rd semester
# ---------------------------
# Ordinary and Partial Differential Equation
# Data Structure
# Data Structure Lab
# Electrical Circuits
# Electrical Circuits Lab
# Discrete Mathematics
# ---------------------------
# Course list Of 4th semester
# ---------------------------
# Engineering Mathematics
# OOP
# OOP Lab
# Bangladesh Studies
# Digital Electronics
# Digital Electronics Lab
# Null
# ---------------------------
# Course list Of 5th semester
# ---------------------------
# Algorithms
# Algorithms Lab
# Electronics Device and Circuits
# Electronics Device and Circuits Lab
# Statistics and Probability
# ---------------------------
# Course list Of 6th semester
# ---------------------------
# Bio Informatics
# Numerical Methods
# Data Communications
# Microprocessors and Assembly Language
# Microprocessors and Assembly Language lab
# ---------------------------
# Course list Of 7th semester
# ---------------------------
# DBMS
# DBMS Lab
# Computer Networks
# Computer Networks Lab
# Economics
# ---------------------------
# Course list Of 8th semester
# ---------------------------
# OS
# OS Lab
# System Analysis and Design
# Computer Architecture
# Art of Living
# ---------------------------
# Course list Of 9th semester
# ---------------------------
# Accounting
# Wireless Programming
# Software Engineering
# Compiler Design
# Compiler Design Lab
# ---------------------------
# Course list Of 10th semester
# ---------------------------
# AI
# AI Lab
# Simulation and Modeling
# Simulation and Modeling Lab
# Web Design
# Web Design Lab
# ---------------------------
# Course list Of 11th semester
# ---------------------------
# Computer Graphics
# Computer Graphics Lab
# Embedded System
# Elective 1
# Project/Internship 1
# ---------------------------
# Course list Of 12th semester
# ---------------------------
# Social and Professional Issue in Computing
# Elective 2
# Project/Internship 2
# ---------------------------
# ---------------------------
# Menu
# ---------------------------
# 1. View Available Course List of All Semester
#
# 2. Add Course :
#
# 3. Mark a Course Done! :
#
# 4. View Updated Course List List :
#
# 5. Exit :
#
# ---------------------------
# Enter Your choice :
# 3
# In Which Semester Are You In ?
# 1
# Enter The Name of the course Which Have been Completed :
# Math 1
# The course Math 1 is removed from the course list
# Course Math 1 is added into Completed Course List!
#
# Do You Want to remove More Course from 1st Semester?
# Yes
# Enter The course name to be removed from the course list :
# Physics 1
# Course Physics 1 is removed from the 1st semester course list
#
# Course Physics 1 is added into Completed Course List!
#
# Do You Want to remove More Course from 1st Semester?
# Yes
# Enter The course name to be removed from the course list :
# Basic Fundamental English
# Course Basic Fundamental English is removed from the 1st semester course list
#
# Course Basic Fundamental English is added into Completed Course List!
#
# Do You Want to remove More Course from 1st Semester?
# No
# ---------------------------
# Menu
# ---------------------------
# 1. View Available Course List of All Semester
#
# 2. Add Course :
#
# 3. Mark a Course Done! :
#
# 4. View Updated Course List List :
#
# 5. Exit :
#
# ---------------------------
# Enter Your choice :
# 3
# In Which Semester Are You In ?
# 2
# Enter The Name of the course Which Have been Completed :
# Programming And Problem Solving
# The course Programming And Problem Solving is removed from the course list
# Course Programming And Problem Solving is added into Completed Course List!
#
# Do You Want to remove More Course from 2nd Semester?
# Yes
# Enter The course name to be removed from the course list :
# Programming And Problem Solving Lab
# Course Programming And Problem Solving Lab is removed from the 2nd semester course list
#
# Course Programming And Problem Solving Lab is added into Completed Course List!
#
# Do You Want to remove More Course from 2nd Semester?
# Yes
# Enter The course name to be removed from the course list :
# Physics 2
# Course Physics 2 is removed from the 2nd semester course list
#
# Course Physics 2 is added into Completed Course List!
#
# Do You Want to remove More Course from 2nd Semester?
# Yes
# Enter The course name to be removed from the course list :
# Physics 2 Lab
# Course Physics 2 Lab is removed from the 2nd semester course list
#
# Course Physics 2 Lab is added into Completed Course List!
#
# Do You Want to remove More Course from 2nd Semester?
# Yes
# Enter The course name to be removed from the course list :
# Writing and Comprehension
# Course Writing and Comprehension is removed from the 2nd semester course list
#
# Course Writing and Comprehension is added into Completed Course List!
#
# Do You Want to remove More Course from 2nd Semester?
# No
# ---------------------------
# Menu
# ---------------------------
# 1. View Available Course List of All Semester
#
# 2. Add Course :
#
# 3. Mark a Course Done! :
#
# 4. View Updated Course List List :
#
# 5. Exit :
#
# ---------------------------
# Enter Your choice :
# 3
# In Which Semester Are You In ?
# 3
# Enter The Name of the course Which Have been Completed :
# Ordinary and Partial Differential Equation
# The course Ordinary and Partial Differential Equation is removed from the course list
# Course Ordinary and Partial Differential Equation is added into Completed Course List!
#
# Do You Want to remove More Course from 3rd Semester?
# yes
# ---------------------------
# Menu
# ---------------------------
# 1. View Available Course List of All Semester
#
# 2. Add Course :
#
# 3. Mark a Course Done! :
#
# 4. View Updated Course List List :
#
# 5. Exit :
#
# ---------------------------
# Enter Your choice :
# Data Structure
# Invalid Choice! Please chose one of 1, 2, 3 or 4
# ---------------------------
# Menu
# ---------------------------
# 1. View Available Course List of All Semester
#
# 2. Add Course :
#
# 3. Mark a Course Done! :
#
# 4. View Updated Course List List :
#
# 5. Exit :
#
# ---------------------------
# Enter Your choice :
# 3
# In Which Semester Are You In ?
# 3
# Enter The Name of the course Which Have been Completed :
# Data Structure
# The course Data Structure is removed from the course list
# Course Data Structure is added into Completed Course List!
#
# Do You Want to remove More Course from 3rd Semester?
# Yes
# Enter The course name to be removed from the course list :
# Data Structure Lab
# Course Data Structure Lab is removed from the 3rd semester course list
#
# Course Data Structure Lab is added into Completed Course List!
#
# Do You Want to remove More Course from 3rd Semester?
# Yes
# Enter The course name to be removed from the course list :
# Electrical Circuits
# Course Electrical Circuits is removed from the 3rd semester course list
#
# Course Electrical Circuits is added into Completed Course List!
#
# Do You Want to remove More Course from 3rd Semester?
# Yes
# Enter The course name to be removed from the course list :
# Electrical Circuits Lab
# Course Electrical Circuits Lab is removed from the 3rd semester course list
#
# Course Electrical Circuits Lab is added into Completed Course List!
#
# Do You Want to remove More Course from 3rd Semester?
# Yes
# Enter The course name to be removed from the course list :
# Discrete Mathematics
# Course Discrete Mathematics is removed from the 3rd semester course list
#
# Course Discrete Mathematics is added into Completed Course List!
#
# Do You Want to remove More Course from 3rd Semester?
# No
# ---------------------------
# Menu
# ---------------------------
# 1. View Available Course List of All Semester
#
# 2. Add Course :
#
# 3. Mark a Course Done! :
#
# 4. View Updated Course List List :
#
# 5. Exit :
#
# ---------------------------
# Enter Your choice :
# 3
# In Which Semester Are You In ?
# 4
# Enter The Name of the course Which Have been Completed :
# Engineering Mathematics
# The course Engineering Mathematics is removed from the course list
# Course Engineering Mathematics is added into Completed Course List!
#
# Do You Want to remove More Course from 4th Semester?
# Yes
# Enter The course name to be removed from the course list :
# OOP
# Course OOP is removed from the 4th semester course list
#
# Course OOP is added into Completed Course List!
#
# Do You Want to remove More Course from 4th Semester?
# Yes
# Enter The course name to be removed from the course list :
# OOP Lab
# Course OOP Lab is removed from the 4th semester course list
#
# Course OOP Lab is added into Completed Course List!
#
# Do You Want to remove More Course from 4th Semester?
# Yes
# Enter The course name to be removed from the course list :
# Bangladesh Studies
# Course Bangladesh Studies  is removed from the 4th semester course list
#
# Course Bangladesh Studies  is added into Completed Course List!
#
# Do You Want to remove More Course from 4th Semester?
# Yes
# Enter The course name to be removed from the course list :
# Digital Electronics
# Course Digital Electronics is removed from the 4th semester course list
#
# Course Digital Electronics is added into Completed Course List!
#
# Do You Want to remove More Course from 4th Semester?
# Yes
# Enter The course name to be removed from the course list :
# Digital Electronics Lab
# Course Digital Electronics Lab is removed from the 4th semester course list
#
# Course Digital Electronics Lab is added into Completed Course List!
#
# Do You Want to remove More Course from 4th Semester?
# Yes
# Enter The course name to be removed from the course list :
# Null
# Course Null is removed from the 4th semester course list
#
# Course Null is added into Completed Course List!
#
# Do You Want to remove More Course from 4th Semester?
# No
# ---------------------------
# Menu
# ---------------------------
# 1. View Available Course List of All Semester
#
# 2. Add Course :
#
# 3. Mark a Course Done! :
#
# 4. View Updated Course List List :
#
# 5. Exit :
#
# ---------------------------
# Enter Your choice :
# 3
# In Which Semester Are You In ?
# 5
# Enter The Name of the course Which Have been Completed :
# Algorithms
# The course Algorithms is removed from the course list
# Course Algorithms is added into Completed Course List!
#
# Do You Want to remove More Course from 5th Semester?
# Yes
# Enter The course name to be removed from the course list :
# Algorithms Lab
# Course Algorithms Lab is removed from the 5th semester course list
#
# Course Algorithms Lab is added into Completed Course List!
#
# Do You Want to remove More Course from 5th Semester?
# Yes
# Enter The course name to be removed from the course list :
# Electronics Device and Circuits
# Course Electronics Device and Circuits is removed from the 5th semester course list
#
# Course Electronics Device and Circuits is added into Completed Course List!
#
# Do You Want to remove More Course from 5th Semester?
# Yes
# Enter The course name to be removed from the course list :
# Electronics Device and Circuits Lab
# Course Electronics Device and Circuits Lab is removed from the 5th semester course list
#
# Course Electronics Device and Circuits Lab is added into Completed Course List!
#
# Do You Want to remove More Course from 5th Semester?
# Yes
# Enter The course name to be removed from the course list :
# Statistics and Probability
# Course Statistics and Probability is removed from the 5th semester course list
#
# Course Statistics and Probability is added into Completed Course List!
#
# Do You Want to remove More Course from 5th Semester?
# Yes
